# %%
#1 Import the function
#import av
import os 
import numpy as np
import skimage as ski
import skimage.feature

import matplotlib.pyplot as plt
from PIL import Image
import random
from scipy.io import loadmat
import math
import seaborn as sns
import seaborn as sns
import pandas as pd
from scipy.stats import wasserstein_distance

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=True,
                          title='Abdomen',
                          cmap=plt.cm.Purples):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    import itertools
    #if normalize:
    #    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    #    print("Normalized confusion matrix")
    #else:
    #    print('Confusion matrix')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title,fontsize=15)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes,fontsize=12)
    plt.yticks(tick_marks, classes,fontsize=12)

    fmt = '.2f' if normalize else 'f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('COPD stages',fontsize=15)
    plt.xlabel('COPD stages',fontsize=15)
    plt.tight_layout()

# %%
abdm=np.load("/content/drive/MyDrive/New_version_copd/distance/abd.npy")

# %%
plt.grid(False) 

#plot_confusion_matrix(cnf_matrix, classes=attack_types, normalize=False, title='Normalized confusion matrix')
plot_confusion_matrix(abdm, classes=['0','1','2','3','4'],
                      title='Abdomen')
# Out:
# [[0.   0.26 0.26 0.21 0.36]
#  [0.26 0.   0.25 0.07 0.25]
#  [0.26 0.25 0.   0.18 0.12]
#  [0.21 0.07 0.18 0.   0.2 ]
#  [0.36 0.25 0.12 0.2  0.  ]]

# %%
abdm=np.load("/content/drive/MyDrive/New_version_copd/distance/ple.npy")
plt.grid(False) 

#plot_confusion_matrix(cnf_matrix, classes=attack_types, normalize=False, title='Normalized confusion matrix')
plot_confusion_matrix(abdm, classes=['0','1','2','3','4'],
                      title='Plethysmograph')
# Out:
# [[0.   0.12 0.09 0.1  0.64]
#  [0.12 0.   0.18 0.03 0.76]
#  [0.09 0.18 0.   0.15 0.58]
#  [0.1  0.03 0.15 0.   0.73]
#  [0.64 0.76 0.58 0.73 0.  ]]
